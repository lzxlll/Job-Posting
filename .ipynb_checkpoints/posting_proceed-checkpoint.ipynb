# %%
import os
import glob
import pandas as pd
from datetime import datetime
import gc

# %%
directory = 'D:/job_posting/mapped_job_posting/'

# %%
df = pd.read_csv('D:/job_posting/mapped_job_posting/job_res_1.csv', on_bad_lines='skip', delimiter= "?", header=None)

# %%
pd.set_option('display.max_columns', None)

# %%
df.rename(columns={0: '招聘主键ID', 1: '公司ID', 2: '公司名称', 3: '城市名称', 4: '公司所在区域', 5: '工作薪酬', 6: '教育要求', 
                   7: '工作经历', 8: '工作描述', 9: '职位名称', 10: '工作名称', 11: '招聘数量', 12: '发布日期', 13: '行业名称', 
                   14: '来源'}, inplace=True)

# %%
df_charac = df[['招聘主键ID', '公司ID', '公司名称', '城市名称', '公司所在区域', '工作薪酬', '教育要求', '工作经历', '职位名称', 
         '工作名称', '招聘数量', '发布日期', '行业名称', '来源']]

# %%
df_desp = df[['招聘主键ID', '公司ID', '工作描述']]

# %%
directory = 'E:/Data/job_posting/mapped_job_posting/'

# iterate over files in that directory
for filename in os.listdir(directory):
    # checking if it is a file
    if filename.startswith("job_res_"): # for files start with a prefix #
        f = os.path.join(directory, filename)
        df = pd.read_csv(f, encoding = "utf_8_sig", on_bad_lines='skip', delimiter= "?", header=None, encoding_errors='ignore')
        df.rename(columns={0: '招聘主键ID', 1: '公司ID', 2: '公司名称', 3: '城市名称', 4: '公司所在区域', 5: '工作薪酬', 6: '教育要求', 
                   7: '工作经历', 8: '工作描述', 9: '职位名称', 10: '工作名称', 11: '招聘数量', 12: '发布日期', 13: '行业名称', 
                   14: '来源'}, inplace=True)
        df_charac = df[['招聘主键ID', '公司ID', '公司名称', '城市名称', '公司所在区域', '工作薪酬', '教育要求', '工作经历', '职位名称', 
         '工作名称', '招聘数量', '发布日期', '行业名称', '来源']]
        df_charac.to_csv('E:/Data/job_posting/processed/charac/{}'.format(filename))

# %%
directory = 'D:/job_posting/mapped_job_posting/'

# iterate over files in that directory
for filename in os.listdir(directory):
    # checking if it is a file
    if filename.startswith("job_res_"): # for files start with a prefix #
        f = os.path.join(directory, filename)
        df = pd.read_csv(f, encoding = "ISO-8859-1", on_bad_lines='skip', delimiter= "?", header=None)
        df.rename(columns={0: '招聘主键ID', 1: '公司ID', 2: '公司名称', 3: '城市名称', 4: '公司所在区域', 5: '工作薪酬', 6: '教育要求', 
                   7: '工作经历', 8: '工作描述', 9: '职位名称', 10: '工作名称', 11: '招聘数量', 12: '发布日期', 13: '行业名称', 
                   14: '来源'}, inplace=True)
        df_desp = df[['招聘主键ID', '公司ID', '工作描述']]
        df_desp.to_csv('C:/Users/DELL/Desktop/posting_tempfile/{}'.format(filename))

# %%
os.chdir("E:/Data/job_posting/processed/charac")
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f, encoding = "utf_8_sig", on_bad_lines='skip', usecols = ['工作名称']) for f in all_filenames], ignore_index=True)

# %%
combined_csv.shape
# Out:
# (80347958, 1)

# %%
# this gets the unique values with their respective frequency
df_counted = combined_csv['工作名称'].value_counts()

# %%
# filter to values > 3
df_filtered = df_counted[df_counted>2]
df_filtered
# Out:
# 销售代表                                      537410
# 销售经理                                      514299
# 会计                                        454074
# 销售专员                                      298929
# 平面设计师                                     271502
#                                            ...
# Electrical Test Engineer(迅达(中国)电梯有限公司)         2
# 消防水电安装监理                                       2
# 实习车陂网络销售食宿全包                                   2
# 物流工程师(博戈橡胶金属(上海)有限公司)                          2
# 秀兰房源一手销售                                       2
# Name: 工作名称, Length: 10323832, dtype: int64

# %%
combined_csv['工作名称'].nunique()
